# %%
ice_cream_rating =8

# %%
sleeping_rating = 6

# %%
first_name = input("Please enter your first name: ")
# Out:
# Please enter your first name:  Mikhail

# %%
last_name = input("Please enter your last name: ")
# Out:
# Please enter your last name:  Kalialin

# %%
my_name = first_name + " " + last_name

# %%
print(my_name)
# Out:
# Mikhail Kalialin

# %%
happiness_rating= (ice_cream_rating + sleeping_rating) / 2

# %%
print(happiness_rating)
# Out:
# 7.0

# %% [markdown]
# Yes. No

# %%
line1 = f"My name is {first_name} and I give eating ice cream a score of {ice_cream_rating} out of 10!"
line2 = f"I am {my_name} and my sleeping enjoyment rating is {sleeping_rating} / 10!"
line3 = f"Based on the factors above, my happiness rating is {happiness_rating} out of 10, or {happiness_rating * 10:.1f}%!"
print(line1)
print(line2)
print(line3)
# Out:
# My name is Mikhail and I give eating ice cream a score of 8 out of 10!
# I am Mikhail Kalialin and my sleeping enjoyment rating is 6 / 10!
# Based on the factors above, my happiness rating is 7.0 out of 10, or 70.0%!
